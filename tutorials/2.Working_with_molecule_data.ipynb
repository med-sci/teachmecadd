# %%
import sys
import os
import pandas as pd
from collections import Counter
import warnings
sys.path.append("../")
warnings.filterwarnings("ignore")
from tcad.tools.datatools import DataLoader, preprocess

# %% [markdown]
# ### Loading activity data for CHEMBL1871 target.

# %%
data_loader = DataLoader('CHEMBL1871')
data_loader.load_data()
data = data_loader.get_data()

data.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        32666                  []    CHEMBL648842
# 1             None        32668                  []    CHEMBL649488
# 2             None        32669                  []    CHEMBL647746
# 3             None        37515                  []    CHEMBL647749
# 4             None        37516                  []    CHEMBL651959
#
#                                    assay_description assay_type  \
# 0  Inhibition of DHT binding to human androgen re...          B
# 1  Antagonistic efficacy for human androgen receptor          F
# 2  Inhibition of human androgen receptor at 10e-1...          B
# 3  Inhibition of 1.0 nM [3H]mibolerone binding to...          B
# 4  Relative binding affinity for human androgen r...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000192  BAO_0000219
# ...

# %% [markdown]
# ### We interested only in subset of columns with useful information

# %%
columns = [
    'assay_type',
    'canonical_smiles', 
    'molecule_chembl_id', 
    'standard_units',
    'standard_value', 
    'target_organism',
    'type',
    ]

data = preprocess(data, *columns)

# %%
filename = "androgen_data.csv"
datapath=os.path.join('../data', filename)
data = data.query("assay_type=='B'&type=='IC50'")

data.to_csv(datapath, index=False)
data.head()
