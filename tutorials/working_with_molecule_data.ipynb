# %%
import sys
import os
import pandas as pd
import warnings
sys.path.append("../")
warnings.filterwarnings("ignore")
from tcad.datatools import DataLoader, preprocess

# %% [markdown]
# ### Loading activity data for CHEMBL1955 target.

# %%
data_loader = DataLoader('CHEMBL1955')
data_loader.load_data()
data = data_loader.get_data()
data.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        34278                  []    CHEMBL820215
# 1             None        37864                  []    CHEMBL820215
# 2             None        40259                  []    CHEMBL820215
# 3             None        42685                  []    CHEMBL820215
# 4             None        46270                  []    CHEMBL820215
#
#                                    assay_description assay_type  \
# 0  Selectivity for Vascular endothelial growth fa...          B
# 1  Selectivity for Vascular endothelial growth fa...          B
# 2  Selectivity for Vascular endothelial growth fa...          B
# 3  Selectivity for Vascular endothelial growth fa...          B
# 4  Selectivity for Vascular endothelial growth fa...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000179  BAO_0000357
# ...

# %% [markdown]
# ### We interested only in subset of columns with useful information

# %%
columns = [
    'assay_type',
    'canonical_smiles', 
    'molecule_chembl_id', 
    'standard_units',
    'standard_value', 
    'target_organism',
    'type',
    ]

data = preprocess(data, *columns)

# %%
datapath=os.path.join('../data', 'data.csv')
data = data.query("assay_type=='B'&type=='IC50'")
data.to_csv(datapath, index=False)
